# %%
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('https://raw.githubusercontent.com/gscdit/Breast-Cancer-Detection/refs/heads/master/data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (569, 33)

# %%
df.drop(columns=['id', 'Unnamed: 32'], inplace=True, errors='ignore')

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
x_train ,X_test ,y_train ,y_test=train_test_split(df.iloc[:,1:],df.iloc[:,0],test_size=0.2)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 108       22.270         19.67          152.80     1509.0          0.13260
# 85        18.460         18.52          121.10     1075.0          0.09874
# 183       11.410         14.92           73.53      402.0          0.09059
# 140        9.738         11.97           61.24      288.5          0.09250
# 370       16.350         23.29          109.00      840.4          0.09742
# ..           ...           ...             ...        ...              ...
# 550       10.860         21.48           68.51      360.5          0.07431
# 89        14.640         15.24           95.77      651.9          0.11320
# 323       20.340         21.51          135.90     1264.0          0.11700
# 378       13.660         15.15           88.27      580.6          0.08268
# 218       19.800         21.56          129.70     1230.0          0.09383
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 108           0.27680         0.42640              0.18230         0.2556
# 85            0.10530         0.13350              0.08795         0.2132
# 183           0.08155         0.06181              0.02361         0.1167
# 140           0.04102         0.00000              0.00000         0.1903
# 370           0.14970         0.18110              0.08773         0.2175
# ..                ...             ...                  ...            ...
# 550           0.04227         0.00000              0.00000         0.1661
# 89            0.13390         0.09966              0.07064         0.2116
# 323           0.18750         0.25650              0.15040         0.2569
# 378           0.07548         0.04249              0.02471         0.1792
# 218           0.13060         0.12720              0.08691         0.2094
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 108                 0.07039  ...         28.40          28.01
# 85                  0.06022  ...         22.93          27.68
# 183                 0.06217  ...         12.37          17.70
# 140                 0.06422  ...         10.62          14.10
# 370                 0.06218  ...         19.38          31.03
# ..                      ...  ...           ...            ...
# 550                 0.05948  ...         11.66          24.77
# 89                  0.06346  ...         16.34          18.24
# 323                 0.06670  ...         25.30          31.86
# 378                 0.05897  ...         14.54          19.64
# 218                 0.05581  ...         25.73          28.64
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 108           206.80      2360.0            0.1701            0.69970
# 85            152.20      1603.0            0.1398            0.20890
# 183            79.12       467.2            0.1121            0.16100
# 140            66.53       342.9            0.1234            0.07204
# 370           129.30      1165.0            0.1415            0.46650
# ..               ...         ...               ...                ...
# 550            74.08       412.3            0.1001            0.07348
# 89            109.40       803.6            0.1277            0.30890
# 323           171.10      1938.0            0.1592            0.44920
# 378            97.96       657.0            0.1275            0.31040
# 218           170.30      2009.0            0.1353            0.32350
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 108           0.9608               0.29100          0.4055
# 85            0.3157               0.16420          0.3695
# 183           0.1648               0.06296          0.1811
# 140           0.0000               0.00000          0.3105
# 370           0.7087               0.22480          0.4824
# ..               ...                   ...             ...
# 550           0.0000               0.00000          0.2458
# 89            0.2604               0.13970          0.3151
# 323           0.5344               0.26850          0.5558
# 378           0.2569               0.10540          0.3387
# 218           0.3617               0.18200          0.3070
#
#      fractal_dimension_worst
# 108                  0.09789
# 85                   0.08579
# 183                  0.07427
# 140                  0.08151
# 370                  0.09614
# ..                       ...
# 550                  0.06592
# 89                   0.08473
# 323                  0.10240
# 378                  0.09638
# 218                  0.08255
#
# [455 rows x 30 columns]

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(X_test)
# Out:
# c:\Users\LOQ\Desktop\adavance_pytohn\env2\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

# %%
X_train_tensor = torch.from_numpy(X_train)
X_test_tensor = torch.from_numpy(X_test)
y_train_tensor = torch.from_numpy(y_train)
y_test_tensor = torch.from_numpy(y_test)

# %%
class MySimpleNN():

  def __init__(self, X):

    self.weights = torch.rand(X.shape[1], 1, dtype=torch.float64, requires_grad=True)
    self.bias = torch.zeros(1, dtype=torch.float64, requires_grad=True)

  def forward(self, X):
    z = torch.matmul(X, self.weights) + self.bias
    y_pred = torch.sigmoid(z)
    return y_pred

  def loss_function(self, y_pred, y):
    # Clamp predictions to avoid log(0)
    epsilon = 1e-7
    y_pred = torch.clamp(y_pred, epsilon, 1 - epsilon)

    # Calculate loss
    loss = -(y_train_tensor * torch.log(y_pred) + (1 - y_train_tensor) * torch.log(1 - y_pred)).mean()
    return loss

# %%
# important parameters
learing_rate=0.1
epoches=25

# %%
model=MySimpleNN(X_train_tensor)
model.weights
# Out:
# tensor([[0.6348],
#         [0.6745],
#         [0.2984],
#         [0.7388],
#         [0.1842],
#         [0.3678],
#         [0.0550],
#         [0.0592],
#         [0.3169],
#         [0.9578],
#         [0.5559],
#         [0.0175],
#         [0.6626],
#         [0.0809],
#         [0.6031],
#         [0.1873],
#         [0.9728],
#         [0.8367],
#         [0.3908],
#         [0.9243],
#         [0.8534],
#         [0.0441],
#         [0.4887],
#         [0.6367],
#         [0.1053],
#         [0.2398],
#         [0.3334],
#         [0.3215],
#         [0.7887],
#         [0.8183]], dtype=torch.float64, requires_grad=True)

# %%
# create model
model = MySimpleNN(X_train_tensor)

# define loop
for epoch in range(epoches):

  # forward pass
  y_pred = model.forward(X_train_tensor)

  # loss calculate
  loss = model.loss_function(y_pred, y_train_tensor)

  # backward pass
  loss.backward()

  # parameters update
  with torch.no_grad():
    model.weights -= learing_rate * model.weights.grad
    model.bias -= learing_rate * model.bias.grad

  # zero gradients
  model.weights.grad.zero_()
  model.bias.grad.zero_()

  # print loss in each epoch
  print(f'Epoch: {epoch + 1}, Loss: {loss.item()}')
# Out:
# Epoch: 1, Loss: 4.06307563349519
# Epoch: 2, Loss: 3.9539668479319006
# Epoch: 3, Loss: 3.8329780762199994
# Epoch: 4, Loss: 3.7039133416412775
# Epoch: 5, Loss: 3.5690828440799183
# Epoch: 6, Loss: 3.430642589822404
# Epoch: 7, Loss: 3.2857789484965103
# Epoch: 8, Loss: 3.138844771592418
# Epoch: 9, Loss: 2.9874731613942354
# Epoch: 10, Loss: 2.831475545317907
# Epoch: 11, Loss: 2.6738830321999214
# Epoch: 12, Loss: 2.5084955922681553
# Epoch: 13, Loss: 2.3414424671836804
# Epoch: 14, Loss: 2.1771307115707677
# Epoch: 15, Loss: 2.0168741562921086
# Epoch: 16, Loss: 1.8542968713548735
# Epoch: 17, Loss: 1.7006432871231278
# Epoch: 18, Loss: 1.5534283182450017
# Epoch: 19, Loss: 1.4161608153661043
# Epoch: 20, Loss: 1.2893754960913457
# Epoch: 21, Loss: 1.1789818732493165
# Epoch: 22, Loss: 1.0858170933602624
# Epoch: 23, Loss: 1.0097950111271186
# Epoch: 24, Loss: 0.9497070953930646
# Epoch: 25, Loss: 0.9033468982336129

# %%
# model evaluation
with torch.no_grad():
  y_pred = model.forward(X_test_tensor)
  y_pred = (y_pred > 0.9).float()
  accuracy = (y_pred == y_test_tensor).float().mean()
  print(f'Accuracy: {accuracy.item()}')
# Out:
# Accuracy: 0.5744844675064087
